# %%
# Password Strength Checker

attempts = 5
while attempts > 0:
    password = input("Enter your password: ")
    score = 0
    if len(password) >= 8:
        score += 1
    if any(char.isdigit() for char in password):
        score += 1
    if any(char.isupper() for char in password):
        score += 1
    if score == 0:
        strength = "Very Weak"
    elif score == 1:
        strength = "Weak"
    elif score == 2:
        strength = "Moderate"
    else:
        strength = "Strong"
    print(f"Password Strength: {strength}")
    if strength == "Strong":
        print(f"You created a strong password!")
        print(f"AI Training Level: Beginner → Intermediate")
        break
    attempts -= 1
    if attempts > 0:
        print(f"Remaining attempts: {attempts}")
        print(f"Try improving your password!\n")
    else:
        print(f"Final Result: Password is not strong enough.")
# Out:
# Enter your password: Saad
# Password Strength: Weak
# Remaining attempts: 4
# Try improving your password!
#
# Enter your password: Saad123
# Password Strength: Moderate
# Remaining attempts: 3
# Try improving your password!
#
# Enter your password: Saad@123
# Password Strength: Strong
# You created a strong password!
# AI Training Level: Beginner → Intermediate
