# %%
def welcome_message():
 print("Welcome to Python Programming Lab ")
welcome_message()
# Out:
# Welcome to Python Programming Lab

# %%
def add_numbers(a,b):
  return a+b
result = add_numbers(10,15)
print("The sum is ",result)
# Out:
# The sum is  25

# %%
def functionA():
    print("Inside Function A")
    functionB()

def functionB():
    print("Inside Function B")


functionA()
# Out:
# Inside Function A
# Inside Function B

# %%
def greet(name="Student"):
    print(f"Hello {name}")
greet()
greet("Saad Ali Khan")
# Out:
# Hello Student
# Hello Saad Ali Khan

# %%
x = 10
def show_function():
    print("Global x =", x)

    y = 20
    print("Local y =", y)

show_function()
print("Global Variable , x =", x)
print("Local Variable , y =", y)
# Out:
# Global x = 10
# Local y = 20
# Global Variable , x = 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_359/395585867.py in <cell line: 0>()
#       8 show_function()
#       9 print("Global Variable , x =", x)
# ---> 10 print("Local Variable , y =", y)
#
# NameError: name 'y' is not defined

# %%
def total_numbers(*numbers):
    total = sum(numbers)
    return total


print("Total Number is : ",total_numbers(23,564,86,22,89,54,34,766,13,86))
# Out:
# Total Number is :  1737

# %%
def student_info(**data):

    for key, value in data.items():
        print(f"{key}: {value}")

student_info(Name="Saad Ali Khan", Age=20,Department="AI")
# Out:
# Name: Saad Ali Khan
# Age: 20
# Department: AI

# %%
Sq=lambda x:x*x
print("Square =",Sq(8))
# Out:
# Square = 64

# %%
numbers=[1,3,5,7,9]
sq=list(map(lambda x:x*x,numbers))
print(sq)
# Out:
# [1, 9, 25, 49, 81]

# %%
numbers=[10,20,50,60,70,93]
greater=list(filter(lambda x:x>50,numbers))
print(greater)
# Out:
# [60, 70, 93]
